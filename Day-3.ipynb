# %%
import pandas as pd
import seaborn as sb
# Load Titanic dataset
titanic = sb.load_dataset("titanic")
# 1. Count missing values
print("Missing values:")
print(titanic.isnull().sum())
# 2. Fill missing age with median
titanic["age"] = titanic["age"].fillna(titanic["age"].median())
# 3. Drop deck because too many values are missing
titanic = titanic.drop("deck", axis=1)
# 4. Fill missing embarked values with mode
titanic["embarked"] = titanic["embarked"].fillna(
    titanic["embarked"].mode()[0])
# 5. Convert sex into numbers
titanic["sex"] = titanic["sex"].map({
    "male": 0,
    "female": 1
})
# 6. Create family size
titanic["family_size"] = titanic["sibsp"] + titanic["parch"] + 1
# 7. Check missing values again
print("\nMissing values after cleaning:")
print(titanic.isnull().sum())
# 8. Look at the cleaned dataset
print("\nCleaned dataset:")
print(titanic.head())
# Out:
# Missing values:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64
#
# Missing values after cleaning:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# family_size    0
# dtype: int64
#
# Cleaned dataset:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500        S  Third    man
# 1         1       1    1  38.0      1      0  71.2833        C  First  woman
# ...
